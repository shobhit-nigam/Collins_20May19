# %%
import requests

# %%
result = requests.get('https://www.oreilly.com/free/')

# %%
result.status_code
# Out:
# 200

# %%
result.headers
# Out:
# {'Server': 'Apache/2.4.7 (Ubuntu)', 'Last-Modified': 'Wed, 22 May 2019 08:32:42 GMT', 'Accept-Ranges': 'bytes', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Content-Type': 'text/html', 'Cache-Control': 'max-age=14313', 'Expires': 'Wed, 22 May 2019 12:41:08 GMT', 'Date': 'Wed, 22 May 2019 08:42:35 GMT', 'Content-Length': '62927', 'Connection': 'keep-alive'}

# %%
result.content
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">\r\n<html>\r\n<head>\r\n\r\n\r\n\r\n<style type="text/css">\r\nli.GlobalNavInfo.right { width: 145px; }\r\n</style>\r\n\r\n\r\n\r\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n<!--chartbeat-->\r\n<script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>\r\n\r\n\r\n\t<title>Free O\'Reilly Books, Ebooks, Webcasts, Conference Sessions, Tutorials, Videos - O\'Reilly Media</title>\n\t<meta name="keywords" content="free O\'Reilly tech books,free online books,free ebooks,free webcasts,free online events,free conference session,free tech tutorials,open books,O\'Reilly Media,O\'Reilly Media" />\n\t<meta name="description" content="A compilation of O\'Reilly Media\'s free products - ebooks, online books, webcast, conference sessions, tutorials, and videos" />\n\t<meta name="date" content="2019-05-22" />\n\t<meta name="search_date" content="2015-
# ...

# %%
result.cookies
# Out:
# <RequestsCookieJar[]>

# %%
from bs4 import BeautifulSoup

# %%
sa = BeautifulSoup(result.content)

# %%
samples = sa.find_all("a", "item-title")

# %%
samples
# Out:
# [<a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781449374433_sampler.pdf">
#  Android Cookbook
#  </a>,
#  <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781491980552_sampler.pdf">
#  Think Perl 6
#  </a>,
#  <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781491952962_sampler.pdf">
#  Practical Statistics for Data Scientists
#  </a>,
#  <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781491923290_sampler.pdf">
#  Spock: Up and Running
#  </a>,
#  <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781491979242_sampler.pdf">
#  iPhone: The Missing Manual
#  </a>,
#  <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781491910399_Sampler.pdf">
#  R for Data Science
#  </a>,
#  <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781491951774_sampler.pdf">
# ...

# %%
samples[1]
# Out:
# <a class="item-title" href="http://cdn.oreillystatic.com/oreilly/booksamplers/9781491980552_sampler.pdf">
# Think Perl 6
# </a>

# %%
data = {}
for a in samples:
    title = a.string.strip()
    data[title] = a.attrs['href']

# %%
data
# Out:
# {'Android Cookbook': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781449374433_sampler.pdf',
#  'Think Perl 6': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491980552_sampler.pdf',
#  'Practical Statistics for Data Scientists': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491952962_sampler.pdf',
#  'Spock: Up and Running': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491923290_sampler.pdf',
#  'iPhone: The Missing Manual': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491979242_sampler.pdf',
#  'R for Data Science': 'http://cdn.oreillystatic.com/oreilly/booksamplers/packt/9781784390860_Sample.pdf',
#  'Building Software Teams': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491951774_sampler.pdf',
#  'macOS Sierra: The Missing Manual': 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491977231_sampler.pdf',
# ...

# %%
type(data)
# Out:
# dict

# %%
data['Think Perl 6']
# Out:
# 'http://cdn.oreillystatic.com/oreilly/booksamplers/9781491980552_sampler.pdf'

# %%
lista = list(data.keys())

# %%
print(lista)
# Out:
# ['Android Cookbook', 'Think Perl 6', 'Practical Statistics for Data Scientists', 'Spock: Up and Running', 'iPhone: The Missing Manual', 'R for Data Science', 'Building Software Teams', 'macOS Sierra: The Missing Manual', 'Practical Machine Learning with H2O', "The Kerbal Player's Guide", 'CSS Refactoring', 'High Performance Images', 'Funded', 'OpenShift for Developers', 'Juniper MX Series', 'Type Inheritance and Relational Theory', 'Mastering CloudForms Automation', 'Learning Rails 5', 'Microservice Architecture', 'Data Analytics with Hadoop', 'Swift Development for the Apple Watch', 'Learning Node', 'Unity 5.x Game Development Blueprints', 'Moodle 3.x Teaching Techniques', 'Flux Architecture', 'Mastering Drupal 8 Views', 'Python Geospatial Development', 'Expert Python Programming', 'Internet of Things with Python', 'Practical Mobile Forensics', 'Cardboard VR Projects for Android', 'Puppet for Containerization', 'Streaming Architecture', 'RStudio for R Statistical Computing Cookbook'
# ...

# %%
len(lista)
# Out:
# 1136

# %%
import smtplib

# %%
sender = 'trainer.nigam@gmail.com'
rcv = 'saitejasripathi@gmail.com'
psw = 'usha.uma'
smtpserver = smtplib.SMTP("smtp.gmail.com", 587)
smtpserver.ehlo()
smtpserver.starttls()
smtpserver.login(sender, psw)
message = 'Subject:Test\nThis is a test msg'
smtpserver.sendmail(sender, rcv, message)
smtpserver.close()
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# <ipython-input-35-e2df6093b8bf> in <module>
#       5 smtpserver.ehlo()
#       6 smtpserver.starttls()
# ----> 7 smtpserver.login(sender, psw)
#       8 message = 'Subject:Test\nThis is a test msg'
#       9 smtpserver.sendmail(sender, rcv, message)
#
# /anaconda3/lib/python3.7/smtplib.py in login(self, user, password, initial_response_ok)
#     728
#     729         # We could not login successfully.  Return result of last attempt.
# --> 730         raise last_exception
#     731
#     732     def starttls(self, keyfile=None, certfile=None, context=None):
#
# /anaconda3/lib/python3.7/smtplib.py in login(self, user, password, initial_response_ok)
#     719                 (code, resp) = self.auth(
#     720                     authmethod, getattr(self, method_name),
# ...

# %%
sender = 'trainer.nigam@gmail.com'
rcv = 'saitejasripathi@gmail.com'
psw = 'usha.uma'
smtpserver = smtplib.SMTP("smtp.gmail.com", 587)
smtpserver.ehlo()
smtpserver.starttls()
smtpserver.login(sender, psw)
message = 'Subject:Test\nThis is a test msg'
smtpserver.sendmail(sender, rcv, message)
smtpserver.close()

# %%
import tkinter

# %%
help(tkinter.Checkbutton)
# Out:
# Help on class Checkbutton in module tkinter:
#
# class Checkbutton(Widget)
#  |  Checkbutton(master=None, cnf={}, **kw)
#  |
#  |  Checkbutton widget which is either in on- or off-state.
#  |
#  |  Method resolution order:
#  |      Checkbutton
#  |      Widget
#  |      BaseWidget
#  |      Misc
#  |      Pack
#  |      Place
#  |      Grid
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, master=None, cnf={}, **kw)
#  |      Construct a checkbutton widget with the parent MASTER.
#  |
#  |      Valid resource names: activebackground, activeforeground, anchor,
#  |      background, bd, bg, bitmap, borderwidth, command, cursor,
#  |      disabledforeground, fg, font, foreground, height,
#  |      highlightbackground, highlightcolor, highlightthickness, image,
#  |      indicatoron, justify, offvalue, onvalue, padx, pady, relief,
#  |      selectcolor, selectimage, state, takefocus, text, textvariable,
# ...
