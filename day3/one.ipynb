# %%
import matplotlib.pyplot as plt

# %%
lista = [4,5,6,7]
plt.plot(lista)

# %%
plt.xlabel("attendance")
plt.ylabel("day")
plt.plot(lista)

# %%
listb = [3, 8, 13, 14]
plt.plot(lista, listb)

# %%
plt.plot(lista, listb, 'red')

# %%
print(lista) 
print(listb)
plt.axis([0,7,0,20])
plt.scatter(lista, listb)
# Out:
# [4, 5, 6, 7]
# [3, 8, 13, 14]

# %%
pass

# %%
print(lista) 
print(listb)
plt.axis([0,7,0,20])
plt.scatter([1, 2, 3, 4], [7, 8, 10, 20])
# Out:
# [4, 5, 6, 7]
# [3, 8, 13, 14]

# %%
help(plt.bar)
# Out:
# Help on function bar in module matplotlib.pyplot:
#
# bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)
#     Make a bar plot.
#
#     The bars are positioned at *x* with the given *align*\ment. Their
#     dimensions are given by *width* and *height*. The vertical baseline
#     is *bottom* (default 0).
#
#     Each of *x*, *height*, *width*, and *bottom* may either be a scalar
#     applying to all bars, or it may be a sequence of length N providing a
#     separate value for each bar.
#
#     Parameters
#     ----------
#     x : sequence of scalars
#         The x coordinates of the bars. See also *align* for the
#         alignment of the bars to the coordinates.
#
#     height : scalar or sequence of scalars
#         The height(s) of the bars.
#
#     width : scalar or array-like, optional
#         The width(s) of the bars (default: 0.8).
#
#     bottom : scalar or array-like, optional
#         The y coordinate(s) of the bars bases (default: 0).
# ...

# %%
listc = ["a", 'b', 'c']
val = [3, 10, 20]
plt.figure(1, figsize = (10, 3))

# %%
plt.show()

# %%
plt.bar(listc, val)
# Out:
# <BarContainer object of 3 artists>

# %%
import scipy

# %%
from scipy import linalg

# %%
# 3x + 4y = 20
# 2x + 3y = 14

# %%
import numpy

# %%
valA = numpy.array([[3, 2], [4, 3]])

# %%
valB = numpy.array([[20], [14]])

# %%
linalg.solve(valA, valB)
# Out:
# array([[ 32.],
#        [-38.]])

# %%
valA.dot(linalg.solve(valA, valB)) - valB
# Out:
# array([[0.],
#        [0.]])

# %%
mat = numpy.array([[8,2], [1,4]])

# %%
linalg.det(mat)
# Out:
# 30.0

# %%
linalg.inv(mat)
# Out:
# array([[ 0.13333333, -0.06666667],
#        [-0.03333333,  0.26666667]])

# %%
print(numpy.__doc__)
# Out:
# NumPy
# =====
#
# Provides
#   1. An array object of arbitrary homogeneous items
#   2. Fast mathematical operations over arrays
#   3. Linear Algebra, Fourier Transforms, Random Number Generation
#
# How to use the documentation
# ----------------------------
# Documentation is available in two forms: docstrings provided
# with the code, and a loose standing reference guide, available from
# `the NumPy homepage <http://www.scipy.org>`_.
#
# We recommend exploring the docstrings using
# `IPython <http://ipython.scipy.org>`_, an advanced Python shell with
# TAB-completion and introspection capabilities.  See below for further
# instructions.
#
# The docstring examples assume that `numpy` has been imported as `np`::
#
#   >>> import numpy as np
#
# Code snippets are indicated by three greater-than signs::
#
#   >>> x = 42
#   >>> x = x + 1
#
# Use the built-in ``help`` function to view a function's docstring::
#
#   >>> help(np.sort)
#   ... # doctest: +SKIP
#
# ...

# %%
import json

# %%
x = '{"name":"jon snow", "age":45, "title":"king in the north"}'

# %%
y = json.loads(x)

# %%
pass

# %%
x
# Out:
# "{'name':'jon snow', 'age':45, 'title':'king in the north'}"

# %%
print(y["title"])
# Out:
# king in the north

# %%
import requests

# %%
requests.get('https://github.com')
# Out:
# <Response [200]>

# %%
#https://github.com/shobhit-nigam
requests.get('https://github.com/shobhit-nigam')
# Out:
# <Response [200]>

# %%
requests.get('https://github.com/shobhit-nigam')
# Out:
# <Response [200]>

# %%
r = requests.get('https://api.github.com')

# %%
r.content
# Out:
# b'{"current_user_url":"https://api.github.com/user","current_user_authorizations_html_url":"https://github.com/settings/connections/applications{/client_id}","authorizations_url":"https://api.github.com/authorizations","code_search_url":"https://api.github.com/search/code?q={query}{&page,per_page,sort,order}","commit_search_url":"https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}","emails_url":"https://api.github.com/user/emails","emojis_url":"https://api.github.com/emojis","events_url":"https://api.github.com/events","feeds_url":"https://api.github.com/feeds","followers_url":"https://api.github.com/user/followers","following_url":"https://api.github.com/user/following{/target}","gists_url":"https://api.github.com/gists{/gist_id}","hub_url":"https://api.github.com/hub","issue_search_url":"https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}","issues_url":"https://api.github.com/issues","keys_url":"https://api.github.com/user/keys","notific
# ...

# %%
r.text
# Out:
# '\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link crossorigin="anonymous" media="all" integrity="sha512-3+HOqCwtQal5hOJQ+mdxiq5zmGOTjF6RhjDsPLxbKDYgGlLFeCwzoIanb7j5IiCuXKUqyC2q8FdkC4nmx2P2rA==" rel="stylesheet" href="https://github.githubassets.com/assets/frameworks-a2fba223d5af91496cac70d4ec3624df.css" />\n  <link crossorigin="anonymous" media="all" integrity="sha512-gH+98Fpr/lalDdrpDSX3pwIw9kTCje5sanzdmIAawwZ9Ix/PGJ3Rgweb
# ...

# %%
r.json()
# Out:
# {'current_user_url': 'https://api.github.com/user',
#  'current_user_authorizations_html_url': 'https://github.com/settings/connections/applications{/client_id}',
#  'authorizations_url': 'https://api.github.com/authorizations',
#  'code_search_url': 'https://api.github.com/search/code?q={query}{&page,per_page,sort,order}',
#  'commit_search_url': 'https://api.github.com/search/commits?q={query}{&page,per_page,sort,order}',
#  'emails_url': 'https://api.github.com/user/emails',
#  'emojis_url': 'https://api.github.com/emojis',
#  'events_url': 'https://api.github.com/events',
#  'feeds_url': 'https://api.github.com/feeds',
#  'followers_url': 'https://api.github.com/user/followers',
#  'following_url': 'https://api.github.com/user/following{/target}',
#  'gists_url': 'https://api.github.com/gists{/gist_id}',
#  'hub_url': 'https://api.github.com/hub',
#  'issue_search_url': 'https://api.github.com/search/issues?q={query}{&page,per_page,sort,order}',
# ...

# %%
type(r)
# Out:
# requests.models.Response

# %%
r.encoding ='utf-8'

# %%
r.headers
# Out:
# {'Server': 'GitHub.com', 'Date': 'Wed, 22 May 2019 05:27:14 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '59', 'X-RateLimit-Reset': '1558506434', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept', 'ETag': 'W/"7dc470913f1fe9bb6c7355b50a0737bc"', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'C
# ...

# %%
#https://www.rockwellcollins.com
r = requests.get('https://www.rockwellcollins.com')

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-83-52b7ec8d97cc> in <module>
# ----> 1 r.json()
#
# /anaconda3/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# /anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /anaconda3/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
# ...

# %%
import requests_html

# %% [raw]
#     from requests_html import HTMLSession

# %%
pass

# %%
session = HTMLSession()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-88-fb0cf7ebd9f4> in <module>
# ----> 1 session = HTMLSession()
#
# NameError: name 'HTMLSession' is not defined

# %%
from requests_html import HTMLSession

# %%
session = HTMLSession()

# %%
r = session.get('https://www.rockwellcollins.com')

# %%
r.html.links
# Out:
# {'/',
#  '/News-and-Events/News-Topic?topic=events',
#  '/Search/Global.aspx?q=&ContentCategory=Pubs',
#  'http://aviationweek.com/special-topics-pages/information-management-solutions',
#  'http://insights.rockwellcollins.com',
#  'http://www.ccs.utc.com/',
#  'http://www.collinsaerospace.com/',
#  'http://www.otis.com/',
#  'http://www.pw.utc.com/',
#  'http://www.utc.com/',
#  'http://www.utc.com/Investors/Pages/Default.aspx',
#  'https://jobs.collinsaerospace.com',
#  'https://modernmilitarytraining.com/',
#  'https://twitter.com/CollinsAero',
#  'https://www.collinsaerospace.com/newsroom',
#  'https://www.collinsaerospace.com/privacy-policy',
#  'https://www.collinsaerospace.com/terms-of-use',
#  'https://www.collinsaerospace.com/who-we-are/about-us',
#  'https://www.collinsaerospace.com/who-we-are/diversity-and-inclusion',
#  'https://www.facebook.com/collinsaerospace/',
#  'https://www.instagram.com/collinsaerospace/',
#  'https://www.linkedin.com/company/collins-aerospace/',
# ...

# %%
r.html.absolute_links
# Out:
# {'http://aviationweek.com/special-topics-pages/information-management-solutions',
#  'http://insights.rockwellcollins.com',
#  'http://www.ccs.utc.com/',
#  'http://www.collinsaerospace.com/',
#  'http://www.otis.com/',
#  'http://www.pw.utc.com/',
#  'http://www.utc.com/',
#  'http://www.utc.com/Investors/Pages/Default.aspx',
#  'https://jobs.collinsaerospace.com',
#  'https://modernmilitarytraining.com/',
#  'https://twitter.com/CollinsAero',
#  'https://www.collinsaerospace.com/newsroom',
#  'https://www.collinsaerospace.com/privacy-policy',
#  'https://www.collinsaerospace.com/terms-of-use',
#  'https://www.collinsaerospace.com/who-we-are/about-us',
#  'https://www.collinsaerospace.com/who-we-are/diversity-and-inclusion',
#  'https://www.facebook.com/collinsaerospace/',
#  'https://www.instagram.com/collinsaerospace/',
#  'https://www.linkedin.com/company/collins-aerospace/',
#  'https://www.rockwellcollins.com/',
# ...

# %%
y = session.get('https://www.python.org/')

# %%
pass

# %%
pass

# %%
z = y.html.find('#about', first=True)

# %%
print(z)
# Out:
# <Element 'li' aria-haspopup='true' class=('tier-1', 'element-1') id='about'>

# %%
print(z.text)
# Out:
# About
# Applications
# Quotes
# Getting Started
# Help
# Python Brochure

# %%
z.attrs
# Out:
# {'aria-haspopup': 'true', 'class': ('tier-1', 'element-1'), 'id': 'about'}
